# %%
from matplotlib import pyplot as plt
import pickle
import pandas as pd
import seaborn as sns
from sklearn.cluster import KMeans

# %%
df = pd.read_csv(
    r"C:\Users\volpir\Downloads\df_manhattan.csv", 
    parse_dates=['tpep_dropoff_datetime','tpep_pickup_datetime'],
    index_col=0,
)

# %%
df.head()
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 1312724         1  2016-06-04 00:00:37   2016-06-04 00:09:56                2
# 1312725         2  2016-06-04 00:00:37   2016-06-04 00:05:25                1
# 1312726         2  2016-06-04 00:00:37   2016-06-04 00:05:32                1
# 1312727         2  2016-06-04 00:00:37   2016-06-04 00:06:57                2
# 1312729         2  2016-06-04 00:00:37   2016-06-04 00:06:11                1
#
#          trip_distance  pickup_longitude  pickup_latitude  RatecodeID  \
# 1312724           1.70        -73.968361        40.755367           1
# 1312725           0.82        -73.975922        40.744919           1
# 1312726           0.89        -74.005150        40.719090           1
# 1312727           1.40        -73.993294        40.724476           1
# 1312729           0.65        -73.983253        40.761059           1
#
# ...

# %%
df_sample = df.sample(100000)
lat_to_lon_ratio = 111049.69/84410.36 # http://www.csgnetwork.com/degreelenllavcalc.html at latitude 40.7831
plt.figure(figsize=(10/lat_to_lon_ratio,10))
plt.scatter(df_sample['pickup_longitude'], df_sample['pickup_latitude'], alpha=0.05, s=3)

# %%
X = df_sample[['pickup_longitude','pickup_latitude']]
